# %%
import numpy as np
import seaborn as sns
from scipy.ndimage import gaussian_filter

# %%
grid = np.load("grid.npy")

# %%
np.save("grid_og.npy",grid)

# %%
smoothed = gaussian_filter(grid, sigma=1.2)
sns.heatmap(smoothed,cbar=False,square=True,xticklabels=False,yticklabels=False)
# Out:
# <Axes: >

# %%
sns.heatmap(gaussian_filter(grid, sigma=1.2))
# Out:
# <Axes: >

# %%
grid
# Out:
# array([[0.20636033, 0.21323905, 0.28843916, ..., 0.28233076, 0.21216603,
#         0.20636033],
#        [0.2063576 , 0.21819357, 0.31557968, ..., 0.25451205, 0.20808581,
#         0.2063576 ],
#        [0.20674739, 0.22156504, 0.33834886, ..., 0.22993347, 0.20725687,
#         0.20674739],
#        ...,
#        [0.2068052 , 0.20716852, 0.23372507, ..., 0.33144403, 0.21997056,
#         0.2068052 ],
#        [0.20638161, 0.20864731, 0.2597218 , ..., 0.3089445 , 0.21677936,
#         0.20638161],
#        [0.20636033, 0.21323905, 0.28843916, ..., 0.28233076, 0.21216603,
#         0.20636033]])
